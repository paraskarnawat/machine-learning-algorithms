# %%
import sys
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

sys.path.append("../../")

from mlalgorithms.regression import OLSRegression, GradientRegression

# %%
X, y = make_regression(n_samples=500, n_features=1, bias=0.5, noise=20, random_state=42)
plt.plot(X, y, 'ro')
plt.xlabel("$X$")
plt.ylabel("$y$")
plt.title("Regression Data Sample")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
model = OLSRegression()
model.fit(X, y)
# Out:
# Mean Squared Error: 394.6944839968718
# R2 Score: 0.9074662292761471
# Coefficients:
#    Feature 1: 63.453982646472326
# Intercept: -0.28344035378122634

# %%
plt.plot(X_test, y_test, 'ro')
plt.plot(X_test, model.predict(X_test), 'b--')
plt.xlabel("$X$")
plt.ylabel("$y$")
plt.title("OLS Regression Model")
plt.show()

# %%
model1 = GradientRegression(n_iters=100, learning_rate=0.03)
model1.fit(X_train, y_train)
# Out:
# Mean Squared Error: 432.9538512896479
# R2 Score: 0.8926819071785148
# Coefficients:
#    Feature 1: 59.3297097665428
# Intercept: 0.02850152010172393

# %%
plt.plot(X_test, y_test, 'ro')
plt.plot(X_test, model.predict(X_test), 'b--')
plt.xlabel("$X$")
plt.ylabel("$y$")
plt.title("OLS Regression Model")
plt.show()

# %%
X, y = make_regression(n_samples=100, n_features=13, noise=20)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
mv_model = OLSRegression(C=0.01)
mv_model.fit(X_train, y_train)
# Out:
# Mean Squared Error: 381.14275148182406
# R2 Score: 0.9854293581964411
# Coefficients:
#    Feature 1: 71.16239044490374
#    Feature 2: 72.66564696045842
#    Feature 3: 74.7127954560165
#    Feature 4: 10.843419521094315
#    Feature 5: 46.373129637274076
#    Feature 6: 1.2497232217229435
#    Feature 7: 14.11768480788183
#    Feature 8: 75.69665665740551
#    Feature 9: 43.48488923823234
#    Feature 10: 84.75865184457183
#    Feature 11: -0.11740951934382338
#    Feature 12: 2.6845617182146055
#    Feature 13: 27.395957528475712
# Intercept: -0.9762639446952388

# %%
mv_model1 = GradientRegression(learning_rate=0.01, regularize=False)
mv_model1.fit(X_train, y_train)
# Out:
# Mean Squared Error: 649.6936355962754
# R2 Score: 0.975162971853666
# Coefficients:
#    Feature 1: 53.32013386806485
#    Feature 2: 62.08570648544338
#    Feature 3: 60.907233548908145
#    Feature 4: 12.04009600060063
#    Feature 5: 52.803254757195425
#    Feature 6: -10.701627692565031
#    Feature 7: 22.838500935067398
#    Feature 8: 69.20959983362398
#    Feature 9: 47.1261661757535
#    Feature 10: 71.07858478760457
#    Feature 11: -2.0796218399485116
#    Feature 12: 3.439725763988164
#    Feature 13: 31.191963272832645
# Intercept: 3.0831844342297203

# %%
print("OLS test MSE: ", mv_model.mean_squared_error(X_test, y_test))
print("Gradient test MSE: ", mv_model1.mean_squared_error(X_test, y_test))
# Out:
# OLS test MSE:  346.87454737651797
# Gradient test MSE:  991.4186370942764

# %%
print("OLS test R2 score: ", mv_model.r2_score(X_test, y_test))
print("Gradient test R2 score: ", mv_model1.r2_score(X_test, y_test))
# Out:
# OLS test R2 score:  0.9857443830628458
# Gradient test R2 score:  0.9592553434039358
